# %%
import pandas as pd
import numpy as np

#import bokeh modules for interactive plotting
import bokeh.charts
import bokeh.charts.utils
import bokeh.io
import bokeh.models
import bokeh.plotting
from bokeh.models import HoverTool, BoxZoomTool, PanTool, SaveTool

from bokeh.palettes import Spectral11

# %%
#data
def reefBoatCount():
    sourceData = pd.read_csv("C:/Users/maalbino/Documents/project_dev/reef_tools/ReefsAerialSurvey_boatcount.csv")
    sourceData['Date'] = pd.to_datetime(sourceData['Date'], format='%m/%d/%Y')
    sourceData.rename(columns={'Number of Boats':'NumberOfBoats','Reef ':'Reef', 'Boat Type':'BoatType'},inplace=True)
    return sourceData
#get source data
#read data to dataframe    
boatCount = reefBoatCount()
boatCount['Year'] = boatCount.Date.map(lambda x: x.year)
#boatCount.head()

#create a palette with a number of colors equal to the number of reef locations
numbars = len(boatCount.groupby('Reef',as_index=False).sum().Reef)
mypalette = Spectral11[0:numbars]

# %%
#by reef

byReef = boatCount.groupby(['Reef','Year'],as_index=False).sum()
byReef
# Out:
#                Reef  Year  NumberOfBoats
# 0    Atlantic Beach  1995           21.0
# 1    Atlantic Beach  1996           19.0
# 2    Atlantic Beach  1997           47.0
# 3    Atlantic Beach  2000           16.0
# 4    Atlantic Beach  2001           80.0
# 5    Atlantic Beach  2002          153.0
# 6    Atlantic Beach  2003          312.0
# 7    Atlantic Beach  2004          120.0
# 8    Atlantic Beach  2005           63.0
# 9    Atlantic Beach  2006           54.0
# 10   Atlantic Beach  2007          125.0
# 11   Atlantic Beach  2008           67.0
# 12   Atlantic Beach  2009            0.0
# 13   Atlantic Beach  2014          139.0
# 14   Atlantic Beach  2015          259.0
# 15      Fire Island  1995           21.0
# 16      Fire Island  1996           29.0
# 17      Fire Island  1997           68.0
# 18      Fire Island  2000           42.0
# 19      Fire Island  2001           64.0
# 20      Fire Island  2002          132.0
# 21      Fire Island  2003          119.0
# 22      Fire Island  2004           94.0
# 23      Fire Island  2005           83.0
# 24      Fire Island  2006           19.0
# 25      Fire Island  2007          118.0
# 26      Fire Island  2008           35.0
# 27      Fire Island  2009            0.0
# 28      Fire Island  2014           72.0
# 29      Fire Island  2015          161.0
# ..              ...   ...            ...
# 134       Smithtown  1995            2.0
# 135       Smithtown  1996           29.0
# 136       Smithtown  1997           34.0
# 137       Smithtown  2000           19.0
# 138       Smithtown  2001           19.0
# 139       Smithtown  2002           11.0
# 140       Smithtown  2003           15.0
# 141       Smithtown  2004           12.0
# 142       Smithtown  2005           14.0
# 143       Smithtown  2006           12.0
# 144       Smithtown  2007           29.0
# 145       Smithtown  2008           15.0
# 146       Smithtown  2009            0.0
# 147       Smithtown  2014           34.0
# 148       Smithtown  2015           57.0
# 149       Yellowbar  1995           36.0
# 150       Yellowbar  1996           44.0
# 151       Yellowbar  1997           71.0
# 152       Yellowbar  2000          104.0
# 153       Yellowbar  2001           46.0
# 154       Yellowbar  2002           31.0
# 155       Yellowbar  2003           27.0
# 156       Yellowbar  2004           14.0
# 157       Yellowbar  2005           25.0
# 158       Yellowbar  2006           13.0
# 159       Yellowbar  2007           27.0
# 160       Yellowbar  2008           21.0
# 161       Yellowbar  2009            0.0
# 162       Yellowbar  2014           35.0
# 163       Yellowbar  2015           41.0
#
# [164 rows x 3 columns]

# %%
hover = HoverTool()
hover.tooltips = [("Reef", "@x")]
myTools = [BoxZoomTool(), PanTool(), SaveTool(), hover]

r = bokeh.plotting.figure(plot_width=750, plot_height=750, title='Total Number of Boats Observed by Reef', tools=myTools)
r.vbar(x=byReef['Year'], stacked=byReef['Reef'],bottom=0, top=byReef['NumberOfBoats'], width=0.5, color='blue')

bokeh.io.show(r)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-b230b437e498> in <module>()
#       6
#       7 r = bokeh.plotting.figure(plot_width=750, plot_height=750, title='Total Number of Boats Observed by Reef', tools=myTools)
# ----> 8 r.vbar(x=byReef['Year'], stacked=byReef['Reef'],bottom=0, top=byReef['NumberOfBoats'], width=0.5, color='blue')
#       9
#      10 bokeh.io.show(r)
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\plotting\helpers.pyc in func(self, *args, **kwargs)
#     422             hglyph_ca = None
#     423
# --> 424         glyph = _make_glyph(glyphclass, kwargs, glyph_ca)
#     425         nsglyph = _make_glyph(glyphclass, kwargs, nsglyph_ca)
#     426         hglyph = _make_glyph(glyphclass, kwargs, hglyph_ca)
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\plotting\helpers.pyc in _make_glyph(glyphclass, kws, extra)
#     129         kws = kws.copy()
#     130         kws.update(extra)
# --> 131         return glyphclass(**kws)
#     132
#     133 def _update_legend(plot, legend_name, glyph_renderer):
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\model.pyc in __init__(self, **kwargs)
#      83         self._id = kwargs.pop("id", make_id())
#      84         self._document = None
# ---> 85         super(Model, self).__init__(**kwargs)
#      86         default_theme.apply_to_model(self)
#      87
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\properties.pyc in __init__(self, **properties)
#     701
#     702         for name, value in properties.items():
# --> 703             setattr(self, name, value)
#     704
#     705     def __setattr__(self, name, value):
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\properties.pyc in __setattr__(self, name, value)
#     722
#     723             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 724                 (name, self.__class__.__name__, text, nice_join(matches)))
#     725
#     726     def set_from_json(self, name, json, models=None):
#
# AttributeError: unexpected attribute 'stacked' to VBar, possible attributes are bottom, fill_alpha, fill_color, line_alpha, line_cap, line_color, line_dash, line_dash_offset, line_join, line_width, name, tags, top, visible, width or x

# %%
byYear = boatCount.groupby('Year', as_index=False).sum()
byYear.sort_values('Year', inplace=True)
years = len(byYear)
mypalette2 = Spectral11[0:years]

# %%
hover = HoverTool()
hover.tooltips = [("Year","@x"),
                 ("Boats", "@top"),]
myTools = [BoxZoomTool(), PanTool(), SaveTool(), hover]
p = bokeh.plotting.figure(background_fill_color='white', plot_width=750, plot_height=750,
                         title='Total Number of Boats Observed Using Reefs by Year (1995-2015)',tools=myTools)
p.vbar(x=byYear['Year'], bottom=0, top=byYear['NumberOfBoats'], width=0.5, color='green')
p.xaxis.axis_label = "Year"
p.yaxis.axis_label = "Boat Counts"

bokeh.io.show(p)
# Out:
# WARNING:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: 4bdf227a-bfd8-406c-89fd-ea6b21a9be13
# WARNING:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: 5b5edd0e-453c-4b92-aca7-0ce758c5dd28
# WARNING:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: 884e0562-7854-4202-b220-b154551bf077
# WARNING:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: df2f3a54-ad44-41b2-9546-6b488cd43226
# WARNING:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: e20b658b-09ec-4984-a456-e99f67fc009d
# WARNING:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: 87e26b4e-cf7c-41f6-acdf-1acf4b2c260f
# ERROR:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:E-1000 (COLUMN_LENGTHS): ColumnDataSource column lengths are not all the same: ColumnDataSource, ViewModel:ColumnDataSource, ref _id: 572148b7-3814-4897-8394-3736af68c604
# ERROR:C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\bokeh\core\validation\check.pyc:E-1000 (COLUMN_LENGTHS): ColumnDataSource column lengths are not all the same: ColumnDataSource, ViewModel:ColumnDataSource, ref _id: 149427e6-e327-4b9f-a0e7-2cfb440f5b81
