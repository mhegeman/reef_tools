# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option("max_columns", None)

# %%
points = pd.read_csv("C:\Users\maalbino\Documents\project_dev\Reefs\NYSDEC_ArtificialReef_CoordGeos2.csv")

# %%
points.head()
# Out:
#                   Site Location   Latitude  Longitude
# 0        Rockaway Reef       NW  40.545500 -73.853500
# 1        Rockaway Reef       NE  40.545500 -73.832000
# 2        Rockaway Reef       SE  40.536667 -73.832000
# 3        Rockaway Reef       SW  40.536667 -73.853500
# 4  Atlantic Beach Reef       NW  40.533667 -73.728333

# %%
plt.scatter(points['Longitude'], points['Latitude'])

# %%
import mplleaflet

plt.scatter(points['Longitude'], points['Latitude'])
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %%
import geopandas as gpd
gateway = gpd.read_file("C:\Users\maalbino\Documents\GIS\GatewayNationalRecreationArea\gate_boundary.shp")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-66952a1b43d8> in <module>()
# ----> 1 import geopandas as gpd
#       2 gateway = gpd.read_file("C:\Users\maalbino\Documents\GIS\GatewayNationalRecreationArea\gate_boundary.shp")
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\geopandas\__init__.pyc in <module>()
#       2 from geopandas.geodataframe import GeoDataFrame
#       3
# ----> 4 from geopandas.io.file import read_file
#       5 from geopandas.io.sql import read_postgis
#       6 from geopandas.tools import sjoin
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\geopandas\io\file.py in <module>()
#       1 import os
#       2
# ----> 3 import fiona
#       4 import numpy as np
#       5 from shapely.geometry import mapping
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\fiona\__init__.py in <module>()
#      67 from six import string_types
#      68
# ---> 69 from fiona.collection import Collection, BytesCollection, vsi_path
#      70 from fiona._drivers import driver_count, GDALEnv
#      71 from fiona.drvsupport import supported_drivers
#
# C:\Users\maalbino\AppData\Local\Continuum\Anaconda2\lib\site-packages\fiona\collection.py in <module>()
#       6
#       7 from fiona import compat
# ----> 8 from fiona.ogrext import Iterator, ItemsIterator, KeysIterator
#       9 from fiona.ogrext import Session, WritingSession
#      10 from fiona.ogrext import (
#
# ImportError: DLL load failed: The specified module could not be found.

# %%
import Fiona
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-66fcd9621a5d> in <module>()
# ----> 1 import Fiona
#
# ImportError: No module named Fiona
